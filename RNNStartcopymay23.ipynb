# %%
import numpy as np
import sklearn.model_selection as sk
import tensorflow as tf
from tensorflow import keras
from keras import layers
from tensorflow.keras.layers import Input
import tensorflow.keras.backend as kb
import matplotlib as mpl
import matplotlib.pyplot as plt
import scipy.io as sio
import random

################################################GONNA SWITCH FROM -1,0,1 to 0,1,2
#gonna work in radians

################### GLOBAL VARIABLES

NUMANGLES = 50 #how many orientations each side can take
MAXPROB = .9


ANGLEMAX = np.pi/2
ANGLEMIN = -np.pi/2

LEFTCHOICEVAL = 0  #Value output when choosing left bar
RIGHTCHOICEVAL = 1 #Value output when choosing right bar

UNITS = 256 # Number of neurons in the dense layer
OUTPUT_SIZE = 2 # Number of output states

STIMULUSDURATION = 1.5 #length of the stimulus (seconds)
PRESTIMULUSDURATION = 1 #length of the pre stimulus (seconds)

FRAMERATE = 12 #(hz)

TOTALFRAMES = int(FRAMERATE*(STIMULUSDURATION + PRESTIMULUSDURATION)) #total number of frames

LASTFRAME = TOTALFRAMES - 1

PRESTIMULUSFRAME = int(PRESTIMULUSDURATION * FRAMERATE - 1)

#################################################3


angleList = np.linspace(ANGLEMAX, ANGLEMIN, NUMANGLES)

def difficulty(angle1, angle2):
    sameSign = True
    difference = abs( abs(angle1) - abs(angle2) )

    if abs(angle1 + angle2) < abs(angle1)+abs(angle2): #if they are opposite sign
        sameSign = False
        
    beta = 0.06 #slope parameter for steepness of difficulty curve (a function of angle separation)
    alpha = .028 #Value of difficulty at angle difference of max

    offset = np.arctanh( 2*alpha - 1 )/beta #shift the graph so at x = 0 f(x) is alpha

    f = .4 #Parameter for the slope of the mapping of difference to input to the difficulty function
    
    if not sameSign: #the angles are not the same side so add a bias to the difficulty
        y = 0.6  #parameter affecting how much f is changed when the angles are on same side or not
        f = f - y*f

    x = 1/(f*difference) #scale it so small differences are large value and big differences are small
    dif = 1/2 * ( np.tanh( beta * (x + offset) ) + 1 )
    return dif


#Generate training data

#list that holds the pairs [left angle, right angle]
anglePairs = []

#generate all pairs of angles
for i in angleList:
    for j in angleList:      #round to deal with floating point error
        decimals = 1
        if (round(i,decimals) != round(j,decimals)) & (-round(i,decimals) != round(j,decimals)): #we dont want any pairs that have equal verticallity (same abs(angle))
            #add noise to the angles
            noiseScale = 10 #scales how noise the angles are
            i += np.random.randn()/noiseScale
            j += np.random.randn()/noiseScale
            anglePairs.append([i,j])


#make the list a np array 
angPair = np.zeros((len(anglePairs), 2))
counter = 0
for i in anglePairs:
    angPair[counter][0] = i[0]
    angPair[counter][1] = i[1]
    counter +=1
anglePairs = angPair

np.random.shuffle(anglePairs)


def correctChoice(angle1, angle2):
    '''input 2 angles return the smaller angle corresponding to more vertical orientation
       Angle 1 is left angle 2 is right. Returns -1 for Left 1 for right
       if they are equal error is thrown because currently only training on non equal angles
    '''
    global LEFTCHOICEVAL, RIGHTCHOICEVAL
    if angle1 < angle2:
        return LEFTCHOICEVAL        #The left bar is oriented more vertically
    elif angle2 < angle1:
        return RIGHTCHOICEVAL        #The right bar is oriented more vertically
    else:
        return "Error. Not expecting equal angles" #throw error if angles are equal


def trainedChoice(angle1, angle2):
    '''Input two angles returns the choice the mouse makes'''
    global MAXPROB, LEFTCHOICEVAL, RIGHTCHOICEVAL

    pCorrect = probablilityCorrect(difficulty(angle1, angle2))

    if pCorrect > MAXPROB:
        pCorrect = MAXPROB

    cor = correctChoice(angle1,angle2)

    n = np.random.random()

    if n <= pCorrect: #if they are certain
        return cor
    else:
          #if not certain then it is a guess
        g = np.random.rand()
        if g < .5:
            return cor
        else:
            if cor == RIGHTCHOICEVAL:
                return LEFTCHOICEVAL
            else:
                return RIGHTCHOICEVAL
            
def probablilityCorrect(difficulty):
    p = -0.5*difficulty + 1
    return p


    
numberTrials = len(anglePairs)

#create the lists of trained and correct choices
corCh = np.zeros(numberTrials) #List of correct choices
trainedCh = np.zeros(numberTrials) #List of trained choices

counter = 0
for i in anglePairs:
    angle1 = i[0]
    angle2 = i[1]
    corCh[counter] = correctChoice(angle1, angle2)
    trainedCh[counter] = trainedChoice(angle1, angle2)
    counter += 1

 




trialsData = np.zeros((numberTrials, TOTALFRAMES, 2)).astype(np.float32) #stores the trials time series'

responseData = np.full((numberTrials, TOTALFRAMES), np.nan) #stores the response time series

#dt =  1/FRAMERATE




for iteration in range(numberTrials): #for each experiment create a time series
    #t = 0
    for frame in range(TOTALFRAMES): 
        if frame <= PRESTIMULUSFRAME: #startwith noise in range [-90 deg, 90 deg] when no stimulus present
            #generate 2 random angles in [-90 deg, 90 deg]
            ang1 = np.random.rand()
            ang1 = ang1 * np.pi/2
            swap = np.random.rand()
            if swap > .5:
                ang1 = -ang1
            ang2 = np.random.rand()
            ang2 = ang2 * np.pi/2
            swap = np.random.rand()
            if swap > .5:
                ang2 = -ang2
            trialsData[iteration][frame][0] = ang1*0
            trialsData[iteration][frame][1] = ang2*0
            if frame == PRESTIMULUSFRAME: #frame before stimulus
                #responseData[iteration][frame] = 1
                u = np.random.rand()
                if u < .5:
                    responseData[iteration][frame] = LEFTCHOICEVAL
                else:
                    responseData[iteration][frame] = RIGHTCHOICEVAL

    
        else:
            #use the angles corresponding to stimulus
            trialsData[iteration][frame][0] = anglePairs[iteration][0]
            trialsData[iteration][frame][1] = anglePairs[iteration][1]
            if frame == LASTFRAME   :#last frame
                responseData[iteration][frame] = trainedCh[iteration]
                
            
 



xTrain, xTest, yTrain, yTest = sk.train_test_split(trialsData, 
                                        responseData, 
                                        test_size=0.25, 
                                        random_state=None)








def custom_loss(y_actual,y_pred): 
    '''calculates the loss using the frame immediately before stimulus and last frame of time series
       The frame before stim is to set p left and p right = 0'''
    l1 = kb.sparse_categorical_crossentropy(y_actual[:, PRESTIMULUSFRAME], y_pred[:, PRESTIMULUSFRAME])
    l2 = kb.sparse_categorical_crossentropy(y_actual[:, LASTFRAME], y_pred[:, LASTFRAME])
    custom_loss = l1 + l2
    return custom_loss


def custom_cat(y_actual,y_pred):
    '''Checks the accuracy of the final predicted output and compares it to the desired output'''
    l2 = tf.keras.metrics.sparse_categorical_accuracy(y_actual[:, LASTFRAME], y_pred[:, LASTFRAME])
    custom_cat = l2
    return custom_cat



model = keras.models.Sequential()
model.add(Input(shape = (xTrain.shape[1], xTrain.shape[2])))
model.add(layers.SimpleRNN(UNITS, activation = 'relu', return_sequences = True, name = 'rnn'))
model.add(layers.BatchNormalization(name = 'batch_norm'))
model.add(layers.Dense(OUTPUT_SIZE, activation = 'softmax', name = 'outputprobs'))

model.summary()


batch_size = 660 # Trials per batch
MAX_EPOCHS = 100 # Total epochs

metrr = ['accuracy', custom_cat]

model.compile(
    loss=custom_loss,
    optimizer="adam",
    metrics=metrr,
)


#print(xTrain.shape)
history = model.fit(xTrain, yTrain, epochs = MAX_EPOCHS, batch_size = batch_size, verbose = True,
   validation_data = (xTest, yTest))
yTestPredict = model.predict(xTest)
#print(yTestPredict.shape, "shapers")


one = []
two = []
three = []


for a in yTestPredict[0]:
    one.append(a[0])
    two.append(a[1])
    #three.append(a[2])



plt.plot(one, c='r')
plt.plot(two, c='g')
#plt.plot(three,c='b')

plt.show()
# Out:
# Model: "sequential_12"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rnn (SimpleRNN)                 │ (None, 30, 256)        │        66,304 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_norm (BatchNormalization) │ (None, 30, 256)        │         1,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ outputprobs (Dense)             │ (None, 30, 2)          │           514 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 67,842 (265.01 KB)
#  Trainable params: 67,330 (263.01 KB)
#  Non-trainable params: 512 (2.00 KB)
# Epoch 1/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 410ms/step - accuracy: 0.0419 - custom_cat: 0.7410 - loss: 1.2764 - val_accuracy: 0.0461 - val_custom_cat: 0.8836 - val_loss: 1.2853
# Epoch 2/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0470 - custom_cat: 0.9197 - loss: 1.0174 - val_accuracy: 0.0462 - val_custom_cat: 0.8870 - val_loss: 1.2543
# Epoch 3/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0477 - custom_cat: 0.9238 - loss: 0.9887 - val_accuracy: 0.0471 - val_custom_cat: 0.9140 - val_loss: 1.2635
# Epoch 4/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0477 - custom_cat: 0.9270 - loss: 0.9867 - val_accuracy: 0.0472 - val_custom_cat: 0.9157 - val_loss: 1.2720
# Epoch 5/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0477 - custom_cat: 0.9226 - loss: 0.9775 - val_accuracy: 0.0466 - val_custom_cat: 0.8988 - val_loss: 1.2623
# Epoch 6/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0484 - custom_cat: 0.9294 - loss: 0.9726 - val_accuracy: 0.0463 - val_custom_cat: 0.8904 - val_loss: 1.2654
# Epoch 7/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0471 - custom_cat: 0.9288 - loss: 0.9594 - val_accuracy: 0.0460 - val_custom_cat: 0.8803 - val_loss: 1.2626
# Epoch 8/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0479 - custom_cat: 0.9310 - loss: 0.9551 - val_accuracy: 0.0461 - val_custom_cat: 0.8853 - val_loss: 1.2572
# Epoch 9/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0479 - custom_cat: 0.9246 - loss: 0.9555 - val_accuracy: 0.0463 - val_custom_cat: 0.8904 - val_loss: 1.2608
# Epoch 10/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0476 - custom_cat: 0.9316 - loss: 0.9456 - val_accuracy: 0.0458 - val_custom_cat: 0.8752 - val_loss: 1.2525
# Epoch 11/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0470 - custom_cat: 0.9331 - loss: 0.9440 - val_accuracy: 0.0460 - val_custom_cat: 0.8820 - val_loss: 1.2548
# Epoch 12/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0482 - custom_cat: 0.9303 - loss: 0.9461 - val_accuracy: 0.0457 - val_custom_cat: 0.8718 - val_loss: 1.2623
# Epoch 13/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0482 - custom_cat: 0.9281 - loss: 0.9463 - val_accuracy: 0.0461 - val_custom_cat: 0.8853 - val_loss: 1.2552
# Epoch 14/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0480 - custom_cat: 0.9309 - loss: 0.9362 - val_accuracy: 0.0463 - val_custom_cat: 0.8904 - val_loss: 1.2459
# Epoch 15/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0483 - custom_cat: 0.9315 - loss: 0.9335 - val_accuracy: 0.0465 - val_custom_cat: 0.8971 - val_loss: 1.2487
# Epoch 16/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0480 - custom_cat: 0.9307 - loss: 0.9350 - val_accuracy: 0.0468 - val_custom_cat: 0.9039 - val_loss: 1.2458
# Epoch 17/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.0477 - custom_cat: 0.9313 - loss: 0.9363 - val_accuracy: 0.0468 - val_custom_cat: 0.9056 - val_loss: 1.2386
# Epoch 18/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0481 - custom_cat: 0.9313 - loss: 0.9308 - val_accuracy: 0.0468 - val_custom_cat: 0.9056 - val_loss: 1.2423
# Epoch 19/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0472 - custom_cat: 0.9344 - loss: 0.9243 - val_accuracy: 0.0471 - val_custom_cat: 0.9140 - val_loss: 1.2365
# Epoch 20/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0481 - custom_cat: 0.9310 - loss: 0.9245 - val_accuracy: 0.0469 - val_custom_cat: 0.9089 - val_loss: 1.2387
# Epoch 21/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0484 - custom_cat: 0.9374 - loss: 0.9156 - val_accuracy: 0.0472 - val_custom_cat: 0.9174 - val_loss: 1.2316
# Epoch 22/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0474 - custom_cat: 0.9308 - loss: 0.9262 - val_accuracy: 0.0472 - val_custom_cat: 0.9157 - val_loss: 1.2354
# Epoch 23/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0478 - custom_cat: 0.9334 - loss: 0.9204 - val_accuracy: 0.0467 - val_custom_cat: 0.9022 - val_loss: 1.2365
# Epoch 24/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0482 - custom_cat: 0.9253 - loss: 0.9310 - val_accuracy: 0.0472 - val_custom_cat: 0.9174 - val_loss: 1.2227
# Epoch 25/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0483 - custom_cat: 0.9374 - loss: 0.9159 - val_accuracy: 0.0472 - val_custom_cat: 0.9157 - val_loss: 1.2294
# Epoch 26/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0485 - custom_cat: 0.9373 - loss: 0.9122 - val_accuracy: 0.0471 - val_custom_cat: 0.9140 - val_loss: 1.2276
# Epoch 27/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0482 - custom_cat: 0.9337 - loss: 0.9204 - val_accuracy: 0.0470 - val_custom_cat: 0.9123 - val_loss: 1.2307
# Epoch 28/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0477 - custom_cat: 0.9345 - loss: 0.9141 - val_accuracy: 0.0473 - val_custom_cat: 0.9191 - val_loss: 1.2236
# Epoch 29/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.0482 - custom_cat: 0.9315 - loss: 0.9220 - val_accuracy: 0.0472 - val_custom_cat: 0.9174 - val_loss: 1.2235
# Epoch 30/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0480 - custom_cat: 0.9297 - loss: 0.9265 - val_accuracy: 0.0471 - val_custom_cat: 0.9140 - val_loss: 1.2110
# Epoch 31/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0479 - custom_cat: 0.9318 - loss: 0.9216 - val_accuracy: 0.0472 - val_custom_cat: 0.9174 - val_loss: 1.2114
# Epoch 32/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0480 - custom_cat: 0.9257 - loss: 0.9210 - val_accuracy: 0.0472 - val_custom_cat: 0.9157 - val_loss: 1.2221
# Epoch 33/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0481 - custom_cat: 0.9287 - loss: 0.9294 - val_accuracy: 0.0470 - val_custom_cat: 0.9123 - val_loss: 1.2064
# Epoch 34/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0470 - custom_cat: 0.9264 - loss: 0.9283 - val_accuracy: 0.0473 - val_custom_cat: 0.9191 - val_loss: 1.2084
# Epoch 35/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0480 - custom_cat: 0.9285 - loss: 0.9196 - val_accuracy: 0.0470 - val_custom_cat: 0.9123 - val_loss: 1.2205
# Epoch 36/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0479 - custom_cat: 0.9218 - loss: 0.9303 - val_accuracy: 0.0472 - val_custom_cat: 0.9174 - val_loss: 1.1992
# Epoch 37/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0473 - custom_cat: 0.9219 - loss: 0.9256 - val_accuracy: 0.0470 - val_custom_cat: 0.9123 - val_loss: 1.1919
# Epoch 38/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0482 - custom_cat: 0.9320 - loss: 0.9252 - val_accuracy: 0.0473 - val_custom_cat: 0.9191 - val_loss: 1.2062
# Epoch 39/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0473 - custom_cat: 0.9319 - loss: 0.9158 - val_accuracy: 0.0473 - val_custom_cat: 0.9207 - val_loss: 1.1965
# Epoch 40/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0482 - custom_cat: 0.9341 - loss: 0.9151 - val_accuracy: 0.0470 - val_custom_cat: 0.9123 - val_loss: 1.1923
# Epoch 41/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0478 - custom_cat: 0.9338 - loss: 0.9155 - val_accuracy: 0.0471 - val_custom_cat: 0.9140 - val_loss: 1.2032
# Epoch 42/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0471 - custom_cat: 0.9323 - loss: 0.9205 - val_accuracy: 0.0473 - val_custom_cat: 0.9207 - val_loss: 1.1792
# Epoch 43/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0479 - custom_cat: 0.9293 - loss: 0.9181 - val_accuracy: 0.0473 - val_custom_cat: 0.9191 - val_loss: 1.1841
# Epoch 44/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0478 - custom_cat: 0.9307 - loss: 0.9107 - val_accuracy: 0.0471 - val_custom_cat: 0.9140 - val_loss: 1.1918
# Epoch 45/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0482 - custom_cat: 0.9320 - loss: 0.9143 - val_accuracy: 0.0472 - val_custom_cat: 0.9174 - val_loss: 1.1773
# Epoch 46/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0483 - custom_cat: 0.9346 - loss: 0.9080 - val_accuracy: 0.0473 - val_custom_cat: 0.9191 - val_loss: 1.1846
# Epoch 47/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0481 - custom_cat: 0.9310 - loss: 0.9178 - val_accuracy: 0.0473 - val_custom_cat: 0.9191 - val_loss: 1.1820
# Epoch 48/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0485 - custom_cat: 0.9350 - loss: 0.9113 - val_accuracy: 0.0472 - val_custom_cat: 0.9157 - val_loss: 1.1724
# Epoch 49/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0473 - custom_cat: 0.9354 - loss: 0.9119 - val_accuracy: 0.0474 - val_custom_cat: 0.9224 - val_loss: 1.1765
# Epoch 50/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0478 - custom_cat: 0.9253 - loss: 0.9263 - val_accuracy: 0.0473 - val_custom_cat: 0.9191 - val_loss: 1.1670
# Epoch 51/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0483 - custom_cat: 0.9362 - loss: 0.9046 - val_accuracy: 0.0473 - val_custom_cat: 0.9191 - val_loss: 1.1644
# Epoch 52/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0473 - custom_cat: 0.9360 - loss: 0.9095 - val_accuracy: 0.0474 - val_custom_cat: 0.9241 - val_loss: 1.1686
# Epoch 53/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0486 - custom_cat: 0.9306 - loss: 0.9101 - val_accuracy: 0.0474 - val_custom_cat: 0.9224 - val_loss: 1.1587
# Epoch 54/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0482 - custom_cat: 0.9343 - loss: 0.9154 - val_accuracy: 0.0473 - val_custom_cat: 0.9191 - val_loss: 1.1637
# Epoch 55/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0466 - custom_cat: 0.9306 - loss: 0.9184 - val_accuracy: 0.0474 - val_custom_cat: 0.9241 - val_loss: 1.1611
# Epoch 56/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0473 - custom_cat: 0.9301 - loss: 0.9136 - val_accuracy: 0.0474 - val_custom_cat: 0.9241 - val_loss: 1.1423
# Epoch 57/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0481 - custom_cat: 0.9323 - loss: 0.9144 - val_accuracy: 0.0474 - val_custom_cat: 0.9241 - val_loss: 1.1500
# Epoch 58/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.0482 - custom_cat: 0.9316 - loss: 0.9094 - val_accuracy: 0.0473 - val_custom_cat: 0.9191 - val_loss: 1.1612
# Epoch 59/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0472 - custom_cat: 0.9309 - loss: 0.9107 - val_accuracy: 0.0473 - val_custom_cat: 0.9191 - val_loss: 1.1385
# Epoch 60/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0486 - custom_cat: 0.9313 - loss: 0.9055 - val_accuracy: 0.0473 - val_custom_cat: 0.9191 - val_loss: 1.1483
# Epoch 61/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0480 - custom_cat: 0.9314 - loss: 0.9139 - val_accuracy: 0.0472 - val_custom_cat: 0.9174 - val_loss: 1.1512
# Epoch 62/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0476 - custom_cat: 0.9326 - loss: 0.9095 - val_accuracy: 0.0473 - val_custom_cat: 0.9191 - val_loss: 1.1342
# Epoch 63/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0476 - custom_cat: 0.9287 - loss: 0.9150 - val_accuracy: 0.0472 - val_custom_cat: 0.9157 - val_loss: 1.1481
# Epoch 64/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0481 - custom_cat: 0.9303 - loss: 0.9088 - val_accuracy: 0.0471 - val_custom_cat: 0.9140 - val_loss: 1.1255
# Epoch 65/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0480 - custom_cat: 0.9259 - loss: 0.9195 - val_accuracy: 0.0474 - val_custom_cat: 0.9224 - val_loss: 1.1247
# Epoch 66/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0464 - custom_cat: 0.9298 - loss: 0.9217 - val_accuracy: 0.0473 - val_custom_cat: 0.9207 - val_loss: 1.1352
# Epoch 67/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0479 - custom_cat: 0.9338 - loss: 0.9056 - val_accuracy: 0.0470 - val_custom_cat: 0.9123 - val_loss: 1.1185
# Epoch 68/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0479 - custom_cat: 0.9305 - loss: 0.9127 - val_accuracy: 0.0473 - val_custom_cat: 0.9191 - val_loss: 1.1303
# Epoch 69/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0483 - custom_cat: 0.9333 - loss: 0.9057 - val_accuracy: 0.0474 - val_custom_cat: 0.9224 - val_loss: 1.1247
# Epoch 70/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0467 - custom_cat: 0.9225 - loss: 0.9263 - val_accuracy: 0.0473 - val_custom_cat: 0.9207 - val_loss: 1.1175
# Epoch 71/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.0477 - custom_cat: 0.9269 - loss: 0.9185 - val_accuracy: 0.0472 - val_custom_cat: 0.9174 - val_loss: 1.1051
# Epoch 72/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0482 - custom_cat: 0.9302 - loss: 0.9099 - val_accuracy: 0.0474 - val_custom_cat: 0.9224 - val_loss: 1.1070
# Epoch 73/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0473 - custom_cat: 0.9304 - loss: 0.9180 - val_accuracy: 0.0473 - val_custom_cat: 0.9207 - val_loss: 1.1161
# Epoch 74/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0482 - custom_cat: 0.9346 - loss: 0.9086 - val_accuracy: 0.0473 - val_custom_cat: 0.9207 - val_loss: 1.1141
# Epoch 75/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0487 - custom_cat: 0.9342 - loss: 0.9088 - val_accuracy: 0.0473 - val_custom_cat: 0.9207 - val_loss: 1.1138
# Epoch 76/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.0478 - custom_cat: 0.9347 - loss: 0.9116 - val_accuracy: 0.0472 - val_custom_cat: 0.9174 - val_loss: 1.1102
# Epoch 77/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0482 - custom_cat: 0.9313 - loss: 0.9156 - val_accuracy: 0.0474 - val_custom_cat: 0.9224 - val_loss: 1.1166
# Epoch 78/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.0473 - custom_cat: 0.9317 - loss: 0.9091 - val_accuracy: 0.0473 - val_custom_cat: 0.9207 - val_loss: 1.0926
# Epoch 79/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.0469 - custom_cat: 0.9316 - loss: 0.9170 - val_accuracy: 0.0473 - val_custom_cat: 0.9191 - val_loss: 1.0944
# Epoch 80/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0483 - custom_cat: 0.9316 - loss: 0.9018 - val_accuracy: 0.0474 - val_custom_cat: 0.9224 - val_loss: 1.0931
# Epoch 81/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0479 - custom_cat: 0.9314 - loss: 0.9098 - val_accuracy: 0.0474 - val_custom_cat: 0.9224 - val_loss: 1.0986
# Epoch 82/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0478 - custom_cat: 0.9294 - loss: 0.9200 - val_accuracy: 0.0473 - val_custom_cat: 0.9191 - val_loss: 1.1004
# Epoch 83/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0482 - custom_cat: 0.9298 - loss: 0.9062 - val_accuracy: 0.0474 - val_custom_cat: 0.9224 - val_loss: 1.0763
# Epoch 84/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0481 - custom_cat: 0.9318 - loss: 0.9112 - val_accuracy: 0.0474 - val_custom_cat: 0.9224 - val_loss: 1.0879
# Epoch 85/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0477 - custom_cat: 0.9273 - loss: 0.9127 - val_accuracy: 0.0474 - val_custom_cat: 0.9224 - val_loss: 1.0885
# Epoch 86/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0481 - custom_cat: 0.9322 - loss: 0.9069 - val_accuracy: 0.0472 - val_custom_cat: 0.9174 - val_loss: 1.0876
# Epoch 87/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0472 - custom_cat: 0.9349 - loss: 0.9077 - val_accuracy: 0.0473 - val_custom_cat: 0.9207 - val_loss: 1.1007
# Epoch 88/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0480 - custom_cat: 0.9251 - loss: 0.9356 - val_accuracy: 0.0473 - val_custom_cat: 0.9191 - val_loss: 1.0889
# Epoch 89/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0482 - custom_cat: 0.9325 - loss: 0.9134 - val_accuracy: 0.0474 - val_custom_cat: 0.9224 - val_loss: 1.0746
# Epoch 90/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0486 - custom_cat: 0.9374 - loss: 0.9099 - val_accuracy: 0.0474 - val_custom_cat: 0.9224 - val_loss: 1.0742
# Epoch 91/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0478 - custom_cat: 0.9313 - loss: 0.9153 - val_accuracy: 0.0473 - val_custom_cat: 0.9207 - val_loss: 1.0708
# Epoch 92/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0475 - custom_cat: 0.9314 - loss: 0.9133 - val_accuracy: 0.0471 - val_custom_cat: 0.9140 - val_loss: 1.0637
# Epoch 93/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0483 - custom_cat: 0.9265 - loss: 0.9173 - val_accuracy: 0.0472 - val_custom_cat: 0.9174 - val_loss: 1.0722
# Epoch 94/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0472 - custom_cat: 0.9284 - loss: 0.9191 - val_accuracy: 0.0473 - val_custom_cat: 0.9191 - val_loss: 1.0775
# Epoch 95/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0475 - custom_cat: 0.9310 - loss: 0.9185 - val_accuracy: 0.0473 - val_custom_cat: 0.9191 - val_loss: 1.0615
# Epoch 96/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0483 - custom_cat: 0.9342 - loss: 0.9070 - val_accuracy: 0.0472 - val_custom_cat: 0.9157 - val_loss: 1.0595
# Epoch 97/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0477 - custom_cat: 0.9312 - loss: 0.9109 - val_accuracy: 0.0473 - val_custom_cat: 0.9191 - val_loss: 1.0513
# Epoch 98/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0473 - custom_cat: 0.9288 - loss: 0.9081 - val_accuracy: 0.0473 - val_custom_cat: 0.9207 - val_loss: 1.0572
# Epoch 99/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0475 - custom_cat: 0.9333 - loss: 0.9037 - val_accuracy: 0.0471 - val_custom_cat: 0.9140 - val_loss: 1.0546
# Epoch 100/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0480 - custom_cat: 0.9290 - loss: 0.9082 - val_accuracy: 0.0473 - val_custom_cat: 0.9191 - val_loss: 1.0404
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
